# %% [markdown]
# - Title: Make a dummy index column
# - Slug: dummy_index
# - Summary: pandas making a dummy index column
# - Date: 2017-04-28 12:00
# - Category: python
# - Tags: pandas
# - Authors: James Loach

# %%
import pandas as pd

# %% [markdown]
# Get a suitable data set and put it in a DataFrame.

# %%
from sklearn.datasets import load_boston
boston = load_boston()
df = pd.DataFrame(boston.data, columns=boston['feature_names'])

# %% [markdown]
# Add a dummy index column.

# %%
df.insert(0, 'ID', 100000 + df.index)

# %%
df.head(10)
# Out:
#        ID     CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  \
# 0  100000  0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900  1.0
# 1  100001  0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671  2.0
# 2  100002  0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671  2.0
# 3  100003  0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622  3.0
# 4  100004  0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622  3.0
# 5  100005  0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622  3.0
# 6  100006  0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605  5.0
# 7  100007  0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505  5.0
# 8  100008  0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821  5.0
# 9  100009  0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921  5.0
#
#      TAX  PTRATIO       B  LSTAT
# 0  296.0     15.3  396.90   4.98
# 1  242.0     17.8  396.90   9.14
# 2  242.0     17.8  392.83   4.03
# 3  222.0     18.7  394.63   2.94
# ...

# %% [markdown]
# Another way to do it, is to reset the index.

# %%
df = pd.DataFrame(boston.data, columns=boston['feature_names'])

df = df.reset_index()

# %%
df.head(10)
# Out:
#    index     CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 0      0  0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900  1.0  296.0
# 1      1  0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671  2.0  242.0
# 2      2  0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671  2.0  242.0
# 3      3  0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622  3.0  222.0
# 4      4  0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622  3.0  222.0
# 5      5  0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622  3.0  222.0
# 6      6  0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605  5.0  311.0
# 7      7  0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505  5.0  311.0
# 8      8  0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821  5.0  311.0
# 9      9  0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921  5.0  311.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# ...
